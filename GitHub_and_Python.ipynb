# %% [markdown]
# <a href="https://colab.research.google.com/github/madhukolan/mk-2/blob/master/GitHub_and_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
File=pd.read_csv("https://raw.githubusercontent.com/madhukolan/mk-2/master/listings.csv")
File.head()
# Out:
#      id  ... availability_365
# 0  2015  ...              141
# 1  2695  ...                0
# 2  3176  ...              220
# 3  3309  ...              297
# 4  7071  ...               26
#
# [5 rows x 16 columns]

# %%
import pandas as pd
import numpy as np
File2=pd.read_csv("https://raw.githubusercontent.com/madhukolan/mk-2/master/neighbourhoods.csv")
File2
# Out:
#           neighbourhood_group                              neighbourhood
# 0        Charlottenburg-Wilm.                                  Barstraße
# 1        Charlottenburg-Wilm.                        Charlottenburg Nord
# 2        Charlottenburg-Wilm.                        Düsseldorfer Straße
# 3        Charlottenburg-Wilm.                            Forst Grunewald
# 4        Charlottenburg-Wilm.                                  Grunewald
# 5        Charlottenburg-Wilm.                                   Halensee
# 6        Charlottenburg-Wilm.                                Heerstrasse
# 7        Charlottenburg-Wilm.                                 Kantstraße
# 8        Charlottenburg-Wilm.                             Kurfürstendamm
# 9        Charlottenburg-Wilm.                           Mierendorffplatz
# 10       Charlottenburg-Wilm.                            Neue Kantstraße
# 11       Charlottenburg-Wilm.                            Otto-Suhr-Allee
# ...
